# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
yelp_url = "https://www.yelp.com/search?cflt=assistedliving&find_loc=Oakland+County%2C+MI"
uClient = uReq(yelp_url)
yelpPage = uClient.read()
yelpPage
#uClient.close()
# Out:
# b'<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/97ea654d5227/assets/img/logos/yelp_burst.svg" content="#c41200"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/118ff475a341/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/
# ...

# %%
yelp_html = bs(yelpPage, "html.parser")
yelp_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = yelp_html.findAll("div", {"class": "businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"})
len(bigboxes)
print(bigboxes)
# Out:
# [<div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 class="css-1l5lt1i"><span class="css-1pxmz4g">1<!-- -->. <a class="css-166la90" href="/biz/lourdes-senior-community-waterford-2" name="Lourdes Senior Community" rel="" target="">Lourdes Senior Community</a></span></h4></div></div>, <div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 class="css-1l5lt1i"><span class="css-1pxmz4g">2<!-- -->. <a class="css-166la90" href="/biz/townehall-place-of-west-bloomfield-west-bloomfield-4" name="Townehall Place of West Bloomfield" rel="" target="">Townehall Place of West Bloomfield</a></span></h4></div></div>, <div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 cl
# ...

# %%
bigboxes[1]
# Out:
# <div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 class="css-1l5lt1i"><span class="css-1pxmz4g">2<!-- -->. <a class="css-166la90" href="/biz/townehall-place-of-west-bloomfield-west-bloomfield-4" name="Townehall Place of West Bloomfield" rel="" target="">Townehall Place of West Bloomfield</a></span></h4></div></div>

# %%
box1 = bigboxes[0]
box1
# Out:
# <div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 class="css-1l5lt1i"><span class="css-1pxmz4g">1<!-- -->. <a class="css-166la90" href="/biz/lourdes-senior-community-waterford-2" name="Lourdes Senior Community" rel="" target="">Lourdes Senior Community</a></span></h4></div></div>

# %%
bigboxes[0]
# Out:
# <div class="businessName__09f24__3Ml2X display--inline-block__09f24__3SvIn border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><h4 class="css-1l5lt1i"><span class="css-1pxmz4g">1<!-- -->. <a class="css-166la90" href="/biz/lourdes-senior-community-waterford-2" name="Lourdes Senior Community" rel="" target="">Lourdes Senior Community</a></span></h4></div></div>

# %%
facilityName = box1.div.find_all('a', {'class': 'css-166la90'})[0].text
facilityName
# Out:
# 'Lourdes Senior Community'

# %%
facilityName = box1.div.find('a', {'class': 'css-166la90'}).text
facilityName
# Out:
# 'Lourdes Senior Community'

# %%
facilityLink = "https://www.yelp.com" + box1.div.a['href']
facilityLink
# Out:
# 'https://www.yelp.com/biz/lourdes-senior-community-waterford-2'

# %%
facilityResponse = requests.get(facilityLink)
facilityResponse
# Out:
# <Response [200]>

# %%
facilityResponse.encoding='utf-8'

# %%
facility_html = bs(facilityResponse.text, "html.parser")
print(facility_html)
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="e6847008">
#             (function() {
#                 var main = null;
#
# ...

# %%
infoBoxes = facility_html.find_all('div',{'class':"arrange__373c0__2iVWK gutter-2__373c0__1a5Xm vertical-align-middle__373c0__2sr2a border-color--default__373c0__r305k"})
infoBoxes
# Out:
# [<div class="arrange__373c0__2iVWK gutter-2__373c0__1a5Xm vertical-align-middle__373c0__2sr2a border-color--default__373c0__r305k"><div class="arrange-unit__373c0__3XPkE arrange-unit-fill__373c0__38Zde border-color--default__373c0__r305k"><p class="css-aml4xx">Business website</p><p class="css-1h1j0y3"><a class="css-ac8spe" href="/biz_redir?url=http%3A%2F%2Fwww.lourdesseniorcommunity.org&amp;cachebuster=1627808236&amp;website_link_type=website&amp;src_bizid=744uqbfaF0eHOAI1GE2Cuw&amp;s=62b92246b8264d99bf2d88131f3f9f1394897b7ffcaad7fc6729ed76c17a3696" name="" rel="noopener nofollow" role="link" target="_blank">lourdesseniorcommunity.org</a></p></div><div class="arrange-unit__373c0__3XPkE border-color--default__373c0__r305k"><span aria-hidden="true" class="icon--24-external-link-v2 icon__373c0__mN9U6 css-1mpk29p"><svg class="icon_svg" height="24" width="24"><path d="M20.47 3.07a.5.5 0 01.53.46v6a.5.5 0 01-.39.49.58.58 0 01-.19 0 .47.47 0 01-.35-.15L17.8 7.6l-5 5a1 1 0 01-1.41 0 1 1 0 0
# ...

# %%
infoBoxes[0]
# Out:
# <div class="arrange__373c0__2iVWK gutter-2__373c0__1a5Xm vertical-align-middle__373c0__2sr2a border-color--default__373c0__r305k"><div class="arrange-unit__373c0__3XPkE arrange-unit-fill__373c0__38Zde border-color--default__373c0__r305k"><p class="css-aml4xx">Business website</p><p class="css-1h1j0y3"><a class="css-ac8spe" href="/biz_redir?url=http%3A%2F%2Fwww.lourdesseniorcommunity.org&amp;cachebuster=1627808236&amp;website_link_type=website&amp;src_bizid=744uqbfaF0eHOAI1GE2Cuw&amp;s=62b92246b8264d99bf2d88131f3f9f1394897b7ffcaad7fc6729ed76c17a3696" name="" rel="noopener nofollow" role="link" target="_blank">lourdesseniorcommunity.org</a></p></div><div class="arrange-unit__373c0__3XPkE border-color--default__373c0__r305k"><span aria-hidden="true" class="icon--24-external-link-v2 icon__373c0__mN9U6 css-1mpk29p"><svg class="icon_svg" height="24" width="24"><path d="M20.47 3.07a.5.5 0 01.53.46v6a.5.5 0 01-.39.49.58.58 0 01-.19 0 .47.47 0 01-.35-.15L17.8 7.6l-5 5a1 1 0 01-1.41 0 1 1 0 01
# ...

# %%
place_website = infoBoxes[0].find_all('p', {'class': 'css-1h1j0y3'})[0].text
place_website
# Out:
# 'lourdesseniorcommunity.org'

# %%
phone_number = infoBoxes[1].find_all('p', {'class': 'css-1h1j0y3'})[0].text
phone_number
# Out:
# '(248) 674-2241'

# %%
address = infoBoxes[2].find_all('p', {'class': 'css-chtywg'})[0].text
address
# Out:
# '2300 Watkins Lake Rd Waterford, MI 48328'
